# %% [markdown]
# # US Cities and Zonal Stats Workflow Example
#
# ## Intro
#
# This notebook provides a quick walk through on how the Sust Global physical risk dataset can be used to make a heatmap based on a collection of asset locations.
#
# We use a sample dataset of [populous US Cities](https://github.com/plotly/datasets/blob/master/us-cities-top-1k.csv) and the zonal climate risk stats from Sust Global to show case an example heatmap created with the folium python library.

# %%
import os
import geopandas as gpd
import pandas as pd
import numpy as np
import folium
from folium import Map
import json
import contextily as ctx
import matplotlib.pyplot as plt
import xarray as xr
import rioxarray as rio 
from shapely.geometry import Polygon, MultiPolygon, shape, Point

# %% [markdown]
# ## Helper Functions

# %%
def folium_heatmap(df, hazard):
    index=0
    m = folium.Map([df['lat'].values[0], df['lng'].values[0]], zoom_start=4, tiles='cartodbpositron')
    for point in range(0, df.shape[0]):
            tooltip_label = str(df['Entity Name'].values[point]) 
            if pd.isnull(df['lat'].values[point]) or pd.isnull(df['lng'].values[point]):
                print('Null/NaN values')
            else:
                scenario_analytics = json.loads(df['scenario_analytics'].values[point])
                label = scenario_analytics['ssp585'][hazard]['summary_label']
                if label == 'HIGH':
                    color = 'red'
                elif label == 'MEDIUM':
                    color = 'yellow'
                else:
                    color = 'green'
                folium.CircleMarker([df['lat'].values[point],df['lng'].values[point]], radius=3, color=color, fill=True, fill_opacity=0.8,fill_color=color, popup=tooltip_label).add_to(m)

    return m

# %% [markdown]
# ## Loading data
#
# Loading data from the US cities sample dataset.

# %%
df = pd.read_csv('./data/USCities.csv', low_memory=False)
pd.set_option('display.max_rows', 1000)
print(df.columns)
print(df.shape)
display(df.head(10))
# Out:
# Index(['City', 'State', 'Population', 'lat', 'lng'], dtype='object')
# (1000, 5)
#          City           State  Population        lat         lng
# 0  Marysville      Washington       63269  48.051764 -122.177082
# 1      Perris      California       72326  33.782519 -117.228648
# 2   Cleveland            Ohio      390113  41.499320  -81.694361
# 3   Worcester   Massachusetts      182544  42.262593  -71.802293
# 4    Columbia  South Carolina      133358  34.000710  -81.034814
# 5   Waterbury     Connecticut      109676  41.558153  -73.051496
# 6       Eagan       Minnesota       65453  44.804132  -93.166886
# 7  Southfield        Michigan       73006  42.473369  -83.221873
# 8   Lafayette       Louisiana      124276  30.224090  -92.019843
# 9  Boise City           Idaho      214237  43.618710 -116.214607

# %% [markdown]
# # Simple Queries on US Cities data
#
# - How many cities exist across the dataset?
# - What is the most populous city?

# %%
len(df)
# Out:
# 1000

# %%
df.nlargest(10, 'Population')
# Out:
#              City         State  Population        lat         lng
# 890      New York      New York     8405837  40.712784  -74.005941
# 953   Los Angeles    California     3884307  34.052234 -118.243685
# 594       Chicago      Illinois     2718782  41.878114  -87.629798
# 646       Houston         Texas     2195914  29.760427  -95.369803
# 53   Philadelphia  Pennsylvania     1553165  39.952584  -75.165222
# 966       Phoenix       Arizona     1513367  33.448377 -112.074037
# 153   San Antonio         Texas     1409019  29.424122  -98.493628
# 333     San Diego    California     1355896  32.715738 -117.161084
# 59         Dallas         Texas     1257676  32.776664  -96.796988
# 805      San Jose    California      998537  37.338208 -121.886329

# %% [markdown]
# # Transform to a geodataframe

# %%
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.lng, df.lat))
gdf = gdf.set_crs("epsg:4326", inplace = True)
print(gdf.crs)
print(gdf.shape)
# Out:
# epsg:4326
# (1000, 6)

# %% [markdown]
# # Load up zonal stats dataset from Sust Global
#
# Use admin 2 for the US here (counties).

# %%
src = './data/USA_2.geojson'

gdf_counties = gpd.read_file(src)
print(gdf_counties.shape)
print(gdf_counties.crs)
display(gdf_counties[:10])
# Out:
# (3234, 14)
# EPSG:4326
#                                   scenario_analytics    id entity_id  \
# 0  { "ssp585": { "wildfire": { "summary_score": 0...     0
# 1  { "ssp585": { "wildfire": { "summary_score": 0...     1
# 2  { "ssp585": { "wildfire": { "summary_score": 0...    10
# 3  { "ssp585": { "wildfire": { "summary_score": 0...   100
# 4  { "ssp585": { "wildfire": { "summary_score": 0...  1000
# 5  { "ssp585": { "wildfire": { "summary_score": 0...  1001
# 6  { "ssp585": { "wildfire": { "summary_score": 0...  1002
# 7  { "ssp585": { "wildfire": { "summary_score": 0...  1003
# 8  { "ssp585": { "wildfire": { "summary_score": 0...  1004
# 9  { "ssp585": { "wildfire": { "summary_score": 0...  1005
#
#   entity_name                                             labels         lng  \
# 0              { "label:fid": 1, "label:LSAD": "06", "label:N...   -81.74317
# 1              { "label:fid": 2, "label:LSAD": "06", "label:N...   -84.46701
# 2              { "label:fid": 11, "label:LSAD": "06", "label:...   -83.56637
# 3              { "label:fid": 101, "label:LSAD": "06", "label...   -83.42110
# 4              { "label:fid": 1001, "label:LSAD": "06", "labe...  -123.09834
# 5              { "label:fid": 1002, "label:LSAD": "06", "labe...  -118.88687
# 6              { "label:fid": 1003, "label:LSAD": "06", "labe...   -91.10702
# 7              { "label:fid": 1004, "label:LSAD": "06", "labe...   -93.66842
# 8              { "label:fid": 1005, "label:LSAD": "06", "labe...   -94.27433
# 9              { "label:fid": 1006, "label:LSAD": "06", "labe...  -120.51611
#
#         lat admin_processing_level admin0      admin1 admin2 admin3 admin4  \
# 0  32.39681                      2    USA     Georgia  13031
# 1  33.79024                      2    USA     Georgia  13121
# 2  34.13387                      2    USA     Georgia  13157
# 3  38.19625                      2    USA    Kentucky  21205
# 4  45.56007                      2    USA      Oregon  41067
# 5  37.93910                      2    USA  California  06051
# 6  36.04122                      2    USA    Arkansas  05075
# 7  33.73538                      2    USA    Arkansas  05057
# 8  35.19884                      2    USA    Arkansas  05131
# 9  39.58037                      2    USA  California  06091
#
#                                             geometry
# 0  POLYGON ((-82.02684 32.55516, -82.03023 32.538...
# 1  POLYGON ((-84.84931 33.51318, -84.85071 33.511...
# 2  POLYGON ((-83.81768 34.12749, -83.816 34.12688...
# 3  POLYGON ((-83.63517 38.19025, -83.6352 38.1875...
# 4  POLYGON ((-123.48544 45.44713, -123.48608 45.4...
# 5  POLYGON ((-119.64894 38.28913, -119.65137 38.2...
# 6  POLYGON ((-91.35694 35.90519, -91.35742 35.890...
# 7  POLYGON ((-93.96945 33.74021, -93.96856 33.737...
# 8  POLYGON ((-94.4476 34.94192, -94.44789 34.9340...
# 9  POLYGON ((-121.05748 39.53999, -121.0582 39.53...

# %%
gdf_counties['scenario_analytics'][0]
# Out:
# '{ "ssp585": { "wildfire": { "summary_score": 0, "summary_label": "LOW", "indicator_baseline": 0, "indicator_baseline_lbd": 0, "indicator_baseline_ubd": 0, "indicator_2030": 0, "indicator_2030_lbd": 0, "indicator_2030_ubd": 0, "indicator_2050": 0, "indicator_2050_lbd": 0, "indicator_2050_ubd": 0, "indicator_2080": 0, "indicator_2080_lbd": 0, "indicator_2080_ubd": 0, "structural_damage_baseline": 0, "structural_damage_baseline_lbd": 0, "structural_damage_baseline_ubd": 0, "structural_damage_2030": 0, "structural_damage_2030_lbd": 0, "structural_damage_2030_ubd": 0, "structural_damage_2050": 0, "structural_damage_2050_lbd": 0, "structural_damage_2050_ubd": 0, "structural_damage_2080": 0, "structural_damage_2080_lbd": 0, "structural_damage_2080_ubd": 0, "business_interruption_baseline": 0, "business_interruption_baseline_lbd": 0, "business_interruption_baseline_ubd": 0, "business_interruption_2030": 0, "business_interruption_2030_lbd": 0, "business_interruption_2030_ubd": 0, "business_interruption_2050": 0, "business_interruption_2050_lbd": 0, "business_interruption_2050_ubd": 0, "business_interruption_2080": 0, "business_interruption_2080_lbd": 0, "business_interruption_2080_ubd": 0 }, "flood": { "summary_score": 0, "summary_label": "LOW", "indicator_baseline": 0, "indicator_baseline_lbd": 0, "indicator_baseline_ubd": 0, "indicator_2030": 0, "indicator_2030_lbd": 0, "indicator_2030_ubd": 0, "indicator_2050": 0, "indicator_2050_lbd": 0, "indicator_2050_ubd": 0, "indicator_2080": 0, "indicator_2080_lbd": 0, "indicator_2080_ubd": 0, "structural_damage_baseline": 0, "structural_damage_baseline_lbd": 0, "structural_damage_baseline_ubd": 0, "structural_damage_2030": 0, "structural_damage_2030_lbd": 0, "structural_damage_2030_ubd": 0, "structural_damage_2050": 0, "structural_damage_2050_lbd": 0, "structural_damage_2050_ubd": 0, "structural_damage_2080": 0, "structural_damage_2080_lbd": 0, "structural_damage_2080_ubd": 0, "business_interruption_baseline": 0, "business_interruption_baseline_lbd": 0, "business_interruption_baseline_ubd": 0, "business_interruption_2030": 0, "business_interruption_2030_lbd": 0, "business_interruption_2030_ubd": 0, "business_interruption_2050": 0, "business_interruption_2050_lbd": 0, "business_interruption_2050_ubd": 0, "business_interruption_2080": 0, "business_interruption_2080_lbd": 0, "business_interruption_2080_ubd": 0 }, "cyclone": { "summary_score": 0.14085, "summary_label": "HIGH", "indicator_baseline": 0.10335999999999999, "indicator_baseline_lbd": 0.10248, "indicator_baseline_ubd": 0.10365000000000001, "indicator_2030": 0.12144000000000001, "indicator_2030_lbd": 0.10849, "indicator_2030_ubd": 0.12565000000000001, "indicator_2050": 0.13952000000000001, "indicator_2050_lbd": 0.1145, "indicator_2050_ubd": 0.14763999999999999, "indicator_2080": 0.14085, "indicator_2080_lbd": 0.11494, "indicator_2080_ubd": 0.14924999999999999, "structural_damage_baseline": 0.0066699999999999997, "structural_damage_baseline_lbd": 0.0066699999999999997, "structural_damage_baseline_ubd": 0.0066699999999999997, "structural_damage_2030": 0.0062300000000000003, "structural_damage_2030_lbd": 0.0060099999999999997, "structural_damage_2030_ubd": 0.0065199999999999998, "structural_damage_2050": 0.0078899999999999994, "structural_damage_2050_lbd": 0.0070000000000000001, "structural_damage_2050_ubd": 0.0087600000000000004, "structural_damage_2080": 0.0078899999999999994, "structural_damage_2080_lbd": 0.0070000000000000001, "structural_damage_2080_ubd": 0.0087600000000000004, "business_interruption_baseline": 0.00677, "business_interruption_baseline_lbd": 0.00677, "business_interruption_baseline_ubd": 0.00677, "business_interruption_2030": 0.0063299999999999997, "business_interruption_2030_lbd": 0.0061000000000000004, "business_interruption_2030_ubd": 0.00662, "business_interruption_2050": 0.0080000000000000002, "business_interruption_2050_lbd": 0.00711, "business_interruption_2050_ubd": 0.0088699999999999994, "business_interruption ...

# %% [markdown]
# # Run a spatial join to get risk metadata for each property
#
# The spatial join will append risk data to the asset dataframe depending on the zone they fall in.

# %%
gdf_risk = gpd.sjoin(gdf, gdf_counties, predicate='within')
print(gdf_risk.shape)
gdf_risk.rename(columns={'lat_left':'lat', 'lng_left':'lng', 'City':'Entity Name'}, inplace=True)
display(gdf_risk.head(10))
# Out:
# (1000, 20)
#   Entity Name           State  Population        lat         lng  \
# 0  Marysville      Washington       63269  48.051764 -122.177082
# 1      Perris      California       72326  33.782519 -117.228648
# 2   Cleveland            Ohio      390113  41.499320  -81.694361
# 3   Worcester   Massachusetts      182544  42.262593  -71.802293
# 4    Columbia  South Carolina      133358  34.000710  -81.034814
# 5   Waterbury     Connecticut      109676  41.558153  -73.051496
# 6       Eagan       Minnesota       65453  44.804132  -93.166886
# 7  Southfield        Michigan       73006  42.473369  -83.221873
# 8   Lafayette       Louisiana      124276  30.224090  -92.019843
# 9  Boise City           Idaho      214237  43.618710 -116.214607
#
#                       geometry  index_right  \
# 0  POINT (-122.17708 48.05176)         3071
# 1  POINT (-117.22865 33.78252)          147
# 2   POINT (-81.69436 41.49932)         3011
# 3   POINT (-71.80229 42.26259)         1724
# 4   POINT (-81.03481 34.00071)         2914
# 5    POINT (-73.0515 41.55815)          324
# 6   POINT (-93.16689 44.80413)          316
# 7   POINT (-83.22187 42.47337)         3131
# 8   POINT (-92.01984 30.22409)         2921
# 9  POINT (-116.21461 43.61871)         2143
#
#                                   scenario_analytics    id entity_id  \
# 0  { "ssp585": { "wildfire": { "summary_score": 0...   852
# 1  { "ssp585": { "wildfire": { "summary_score": 0...   113
# 2  { "ssp585": { "wildfire": { "summary_score": 0...   799
# 3  { "ssp585": { "wildfire": { "summary_score": 0...   255
# 4  { "ssp585": { "wildfire": { "summary_score": 0...   710
# 5  { "ssp585": { "wildfire": { "summary_score": 8...   129
# 6  { "ssp585": { "wildfire": { "summary_score": 0...  1282
# 7  { "ssp585": { "wildfire": { "summary_score": 0...   906
# 8  { "ssp585": { "wildfire": { "summary_score": 0...   717
# 9  { "ssp585": { "wildfire": { "summary_score": 0...  2927
#
#   entity_name                                             labels   lng_right  \
# 0              { "label:fid": 853, "label:LSAD": "06", "label...  -121.69719
# 1              { "label:fid": 114, "label:LSAD": "06", "label...  -115.99385
# 2              { "label:fid": 800, "label:LSAD": "06", "label...   -81.65860
# 3              { "label:fid": 256, "label:LSAD": "06", "label...   -71.90774
# 4              { "label:fid": 711, "label:LSAD": "06", "label...   -80.90310
# 5              { "label:fid": 130, "label:LSAD": "06", "label...   -72.93219
# 6              { "label:fid": 1283, "label:LSAD": "06", "labe...   -93.06544
# 7              { "label:fid": 907, "label:LSAD": "06", "label...   -83.38580
# 8              { "label:fid": 718, "label:LSAD": "15", "label...   -92.06391
# 9              { "label:fid": 2928, "label:LSAD": "06", "labe...  -116.24116
#
#   lat_right admin_processing_level admin0          admin1 admin2 admin3 admin4
# 0  48.04736                      2    USA      Washington  53061
# 1  33.74368                      2    USA      California  06065
# 2  41.42430                      2    USA            Ohio  39035
# 3  42.35142                      2    USA   Massachusetts  25027
# 4  34.02185                      2    USA  South Carolina  45079
# 5  41.41063                      2    USA     Connecticut  09009
# 6  44.67188                      2    USA       Minnesota  27037
# 7  42.66039                      2    USA        Michigan  26125
# 8  30.20683                      2    USA       Louisiana  22055
# 9  43.45112                      2    USA           Idaho  16001

# %% [markdown]
# # Plot on slippy map as heatmap
#
# You can pass hazard value as one of the following: 'wildfire', 'flood', 'cyclone', 'heatwave', 'sea_level_rise', 'water_stress'.

# %%
m = folium_heatmap(gdf_risk, 'cyclone')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18733ff32d42fbce16436f023a3e29c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18733ff32d42fbce16436f023a3e29c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18733ff32d42fbce16436f023a3e29c2 = L.map(
#                 &quot;map_18733ff32d42fbce16436f023a3e29c2&quot;,
#                 {
#                     center: [48.0517637, -122.1770818],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_26eb08d8027c689898cbc35ad59a6c71 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_26eb08d8027c689898cbc35ad59a6c71.addTo(map_18733ff32d42fbce16436f023a3e29c2);
#
#
#             var circle_marker_c9b238d51cf7fd7e99591b84c2d2ad1a = L.circleMarker(
#                 [48.0517637, -122.1770818],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_18733ff32d42fbce16436f023a3e29c2);
#
#
#         var popup_0c21f40d837eb1c033d142bc5f9cc08a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b487212c2b20d7ce3c9fa884ec9a252 = $(`&lt;div id=&quot;html_4b487212c2b20d7ce3c9fa884ec9a252&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marysville&lt;/div&gt;`)[0];
#                 popup_0c21f40d837eb1c033d142bc5f9cc08a.setContent(html_4b487212c2b20d7ce3c9fa884ec9a252);
#
#
#
#         circle_marker_c9b238d51cf7fd7e99591b84c2d2ad1a.bindPopup(popup_0c21f40d837eb1c033d142bc5f9cc08a)
#         ;
#
#
#
#
#             var circle_marker_abffd84de602d2268f40fd9b5763b669 = L.circleMarker(
#                 [33.7825194, -117.2286478],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_18733ff32d42fbce16436f023a3e29c2);
#
#
#         var popup_09637281d0e11805a24b3b9934d12c57 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_74769e4f79975a2e6c55495e3a9c9537 = $(`&lt;div id=&quot;html_74769e4f79975a2e6c55495e3a9c9537&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perris&lt;/div&gt;`)[0];
#                 popup_09637281d0e11805a24b3b9934d12c57.setContent(html_74769e4f79975a2e6c55495e3a9c9537);
#
#
#
#         circle_marker_abffd84de602d2268f40fd9b5763b669.bindPopup(popup_09637281d0e11805a24b3b9934d12c57)
#         ;
#
#
#
#
#             var circle_marker_738d5015f4b3a18bb701d2775a8046a8 = L.circleMarker(
#                 [41.49932, -81.6943605],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_18733ff32d42fbce16436f023a3e29c2);
#
#
#         var popup_194d09a864d98568a334b0b835483fed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_414a7dfc015bca48f6c58356fd316f67 = $(`&lt;div id=&quot;html_414a7dfc015bca48f6c58356fd316f67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cleveland&lt;/div&gt;`)[0];
#                 popup_194d09a864d98568a334b0b835483fed.setContent(html_414a7dfc015bca48f6c58356fd316f67);
#
#
#
#         circle_marker_738d5015f4b3a18bb701d2775a8046a8.bindPopup(popup_194d09a864d98568a334b0b835483fed)
#         ;
#
#
#
#
#             var circle_marker_208aa50521a0b73133046a21342e3325 = L.circleMarker(
#                 [42.262593200000005, -71.8022934],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quo
